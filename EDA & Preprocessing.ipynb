# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('laptop_data.csv')
df.shape
# Out:
# (1303, 12)

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df.nunique()
# Out:
# Company              19
# TypeName              6
# Inches               18
# ScreenResolution     40
# Cpu                 118
# Ram                   9
# Memory               39
# Gpu                 110
# OpSys                 9
# Weight              179
# Price               791
# dtype: int64

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
catcols = ['Company','TypeName','OpSys']

# %%
df[catcols]
# Out:
#      Company            TypeName       OpSys
# 0      Apple           Ultrabook       macOS
# 1      Apple           Ultrabook       macOS
# 2         HP            Notebook       No OS
# 3      Apple           Ultrabook       macOS
# 4      Apple           Ultrabook       macOS
# ...      ...                 ...         ...
# 1298  Lenovo  2 in 1 Convertible  Windows 10
# 1299  Lenovo  2 in 1 Convertible  Windows 10
# 1300  Lenovo            Notebook  Windows 10
# 1301      HP            Notebook  Windows 10
# 1302    Asus            Notebook  Windows 10
#
# [1303 rows x 3 columns]

# %%
fig, axes = plt.subplots(1,len(catcols),figsize=(15,7))
plt.xticks(rotation='vertical')

for i, feature in enumerate(catcols):
    sns.countplot(x=feature,data=df,ax=axes[i])
    axes[i].set_title(feature)
    axes[i].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
# for OpSys, create grouping cateogries on windows, mac, linux and other os

def cateorize_os(text):
    if 'windows' in text.lower():
        return 'Windows OS'
    elif 'mac' in text.lower():
        return 'Mac OS'
    elif 'linux' in text.lower():
        return 'Linux'
    else:
        return 'Other OS'

# %%
df['OS'] = df['OpSys'].apply(cateorize_os)

# %%
df['OS'].value_counts()
# Out:
# OS
# Windows OS    1125
# Other OS        95
# Linux           62
# Mac OS          21
# Name: count, dtype: int64

# %%
catcols = ['Company','TypeName','OS']

# %%
fig, axes = plt.subplots(1,len(catcols),figsize=(15,7))
plt.xticks(rotation='vertical')

for i, feature in enumerate(catcols):
    sns.barplot(x=feature,y='Price',data=df,ax=axes[i])
    axes[i].set_title(feature)
    axes[i].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'Price', 'OS'],
#       dtype='object')

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
# extract resolution and display type from ScreenResolution

def screen_type(text):
    if 'ips' in text.lower():
        return 'IPS'
    elif 'touchscreen' in text.lower():
        return 'TouchScreen'
    else:
        return 'Other Types'

# %%
df['Display_type'] = df['ScreenResolution'].apply(screen_type)

# %%
df['Display_type'].value_counts()
# Out:
# Display_type
# Other Types    831
# IPS            365
# TouchScreen    107
# Name: count, dtype: int64

# %%
df['Screen_Resolution'] = df['ScreenResolution'].apply(lambda x: x.split(' ')[-1])

# %%
df['Screen_Resolution'].value_counts()
# Out:
# Screen_Resolution
# 1920x1080    841
# 1366x768     308
# 3840x2160     43
# 3200x1800     27
# 2560x1440     23
# 1600x900      23
# 2560x1600      6
# 2304x1440      6
# 2256x1504      6
# 1920x1200      5
# 1440x900       4
# 2880x1800      4
# 2400x1600      4
# 2160x1440      2
# 2736x1824      1
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Company              0
# TypeName             0
# Inches               0
# ScreenResolution     0
# Cpu                  0
# Ram                  0
# Memory               0
# Gpu                  0
# OpSys                0
# Weight               0
# Price                0
# OS                   0
# Display_type         0
# Screen_Resolution    0
# dtype: int64

# %%
# create megapixel , h_pixel & v_pixel
df['h_pixel'] = df['Screen_Resolution'].apply(lambda x: x.split('x')[0]).astype(int)
df['v_pixel'] = df['Screen_Resolution'].apply(lambda x: x.split('x')[-1]).astype(int)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
# Total Megapixels = (Horizontal Resolution x Vertical Resolution) / 1,000,000 --- Formula for megapixels

df['megapixel'] = round((df['h_pixel'] * df['v_pixel']) / 1000000,1)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
sns.scatterplot(x='megapixel',y='Price',data=df)
plt.show()

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df[df['Cpu'].str.contains('M',case=False,na=False)]
# Out:
#      Company   TypeName  Inches                    ScreenResolution  \
# 5       Acer   Notebook    15.6                            1366x768
# 14     Apple  Ultrabook    12.0  IPS Panel Retina Display 2304x1440
# 20      Asus    Netbook    11.6                            1366x768
# 22        HP   Notebook    15.6                            1366x768
# 30     Chuwi   Notebook    15.6                   Full HD 1920x1080
# ...      ...        ...     ...                                 ...
# 1266      HP   Notebook    15.6                   Full HD 1920x1080
# 1275    Asus  Ultrabook    13.3         IPS Panel Full HD 1920x1080
# 1280      HP   Notebook    15.6                   Full HD 1920x1080
# 1289    Asus  Ultrabook    13.3         IPS Panel Full HD 1920x1080
# 1294      HP   Notebook    15.6                   Full HD 1920x1080
#
#                                Cpu  Ram              Memory  \
# 5          AMD A9-Series 9420 3GHz  4GB           500GB HDD
# ...

# %%
df[df['Company'] == 'Apple']
# Out:
#      Company   TypeName  Inches                    ScreenResolution  \
# 0      Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1      Apple  Ultrabook    13.3                            1440x900
# 3      Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4      Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 6      Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 7      Apple  Ultrabook    13.3                            1440x900
# 12     Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 14     Apple  Ultrabook    12.0  IPS Panel Retina Display 2304x1440
# 15     Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 17     Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 26     Apple  Ultrabook    13.3                            1440x900
# 34     Apple  Ultrabook    13.3                            1440x900
# 45     Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# ...

# %%
df['CPU_Brand'] = df['Cpu'].apply(lambda x:'Intel' if 'intel' in x.lower() else ('AMD' if 'amd' in x.lower() else 'Other'))

# %%
df['CPU_Brand'].value_counts()
# Out:
# CPU_Brand
# Intel    1240
# AMD        62
# Other       1
# Name: count, dtype: int64

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8GB     619
# 4GB     375
# 16GB    200
# 6GB      41
# 12GB     25
# 2GB      22
# 32GB     17
# 24GB      3
# 64GB      1
# Name: count, dtype: int64

# %%
df['RAM'] = df['Ram'].apply(lambda x:x.split('GB')[0]).astype(int)

# %%
df['RAM'].value_counts()
# Out:
# RAM
# 8     619
# 4     375
# 16    200
# 6      41
# 12     25
# 2      22
# 32     17
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1303 non-null   object
#  1   TypeName           1303 non-null   object
#  2   Inches             1303 non-null   float64
#  3   ScreenResolution   1303 non-null   object
#  4   Cpu                1303 non-null   object
#  5   Ram                1303 non-null   object
#  6   Memory             1303 non-null   object
#  7   Gpu                1303 non-null   object
#  8   OpSys              1303 non-null   object
#  9   Weight             1303 non-null   object
#  10  Price              1303 non-null   float64
#  11  OS                 1303 non-null   object
#  12  Display_type       1303 non-null   object
#  13  Screen_Resolution  1303 non-null   object
#  14  h_pixel            1303 non-null   int32
#  15  v_pixel            1303 non-null   int32
# ...

# %%
df['Memory0'] = df['Memory'].apply(lambda x:x.split(' + ')[0])
df['Memory1'] = df['Memory'].apply(lambda x:x.split(' + ')[-1])

# %%
df['Memory1'].value_counts()
# Out:
# Memory1
# 256GB SSD              412
# 1TB HDD                223
#  1TB HDD               185
# 500GB HDD              132
# 512GB SSD              118
# 128GB SSD               76
# 32GB Flash Storage      38
# 2TB HDD                 16
#  2TB HDD                15
# 64GB Flash Storage      15
# 1TB SSD                 14
# 1.0TB Hybrid             9
# 256GB Flash Storage      8
# 16GB Flash Storage       7
# 32GB SSD                 6
# 180GB SSD                5
# 128GB Flash Storage      4
# 16GB SSD                 3
#  256GB SSD               3
#  500GB HDD               2
# 512GB Flash Storage      2
#  1.0TB Hybrid            2
#  512GB SSD               1
# 64GB SSD                 1
# 32GB HDD                 1
# 128GB HDD                1
# 240GB SSD                1
# 8GB SSD                  1
# 508GB Hybrid             1
# 1.0TB HDD                1
# Name: count, dtype: int64

# %% [markdown]
# 1TB HDD, 1TB HDD

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df[df['Memory'] == '512GB SSD +  1TB HDD']
# Out:
#      Company TypeName  Inches                 ScreenResolution  \
# 177      MSI   Gaming    18.4                Full HD 1920x1080
# 200     Dell   Gaming    15.6  IPS Panel 4K Ultra HD 3840x2160
# 203   Lenovo   Gaming    15.6      IPS Panel Full HD 1920x1080
# 238     Asus   Gaming    17.3                Full HD 1920x1080
# 258      MSI   Gaming    17.3                Full HD 1920x1080
# 578      MSI   Gaming    17.3                Full HD 1920x1080
# 659     Dell   Gaming    17.3  IPS Panel 4K Ultra HD 3840x2160
# 811      MSI   Gaming    17.3                Full HD 1920x1080
# 840     Asus   Gaming    17.3                Full HD 1920x1080
# 841     Dell   Gaming    17.3      IPS Panel Full HD 1920x1080
# 939     Dell   Gaming    17.3                        2560x1440
# 945   Lenovo   Gaming    15.6      IPS Panel Full HD 1920x1080
# 955     Dell   Gaming    17.3  IPS Panel 4K Ultra HD 3840x2160
# 1197    Asus   Gaming    17.3      IPS Panel Full HD 1920x1080
#
# ...

# %%
df.drop(columns=['Memory1','Memory0'],inplace=True)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['Primary_Storage'] = df['Memory'].apply(lambda x:x.split('+')[0])
df['Secondary_Storage'] = df['Memory'].apply(lambda x:x.split('+')[-1])

# %%
df['Secondary_Storage'] = df.apply(lambda x: '0GB' if x['Primary_Storage'] == x['Secondary_Storage'] else x['Secondary_Storage'],axis=1)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df[df['Memory'] == '512GB SSD +  1TB HDD']
# Out:
#      Company TypeName  Inches                 ScreenResolution  \
# 177      MSI   Gaming    18.4                Full HD 1920x1080
# 200     Dell   Gaming    15.6  IPS Panel 4K Ultra HD 3840x2160
# 203   Lenovo   Gaming    15.6      IPS Panel Full HD 1920x1080
# 238     Asus   Gaming    17.3                Full HD 1920x1080
# 258      MSI   Gaming    17.3                Full HD 1920x1080
# 578      MSI   Gaming    17.3                Full HD 1920x1080
# 659     Dell   Gaming    17.3  IPS Panel 4K Ultra HD 3840x2160
# 811      MSI   Gaming    17.3                Full HD 1920x1080
# 840     Asus   Gaming    17.3                Full HD 1920x1080
# 841     Dell   Gaming    17.3      IPS Panel Full HD 1920x1080
# 939     Dell   Gaming    17.3                        2560x1440
# 945   Lenovo   Gaming    15.6      IPS Panel Full HD 1920x1080
# 955     Dell   Gaming    17.3  IPS Panel 4K Ultra HD 3840x2160
# 1197    Asus   Gaming    17.3      IPS Panel Full HD 1920x1080
#
# ...

# %%
df['Primary_Storage1'] = df['Primary_Storage'].str.replace('Flash Storage','SSD')

# %%
df.drop(columns=['Primary_Storage1'],inplace=True)

# %%
df['Primary_Storage'] = df['Primary_Storage'].str.replace('Flash Storage','SSD')
df['Secondary_Storage'] = df['Secondary_Storage'].str.replace('Flash Storage','SSD')

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['Primary_type'] = df['Primary_Storage'].apply(lambda x:'SSD' if 'SSD' in x else 'HDD')
df['Secondary_type'] = df['Secondary_Storage'].apply(lambda x:'SSD' if 'SSD' in x else ('-' if x == '-' else 'HDD'))

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df[df['Memory'] == '512GB SSD +  1TB HDD']
# Out:
#      Company TypeName  Inches                 ScreenResolution  \
# 177      MSI   Gaming    18.4                Full HD 1920x1080
# 200     Dell   Gaming    15.6  IPS Panel 4K Ultra HD 3840x2160
# 203   Lenovo   Gaming    15.6      IPS Panel Full HD 1920x1080
# 238     Asus   Gaming    17.3                Full HD 1920x1080
# 258      MSI   Gaming    17.3                Full HD 1920x1080
# 578      MSI   Gaming    17.3                Full HD 1920x1080
# 659     Dell   Gaming    17.3  IPS Panel 4K Ultra HD 3840x2160
# 811      MSI   Gaming    17.3                Full HD 1920x1080
# 840     Asus   Gaming    17.3                Full HD 1920x1080
# 841     Dell   Gaming    17.3      IPS Panel Full HD 1920x1080
# 939     Dell   Gaming    17.3                        2560x1440
# 945   Lenovo   Gaming    15.6      IPS Panel Full HD 1920x1080
# 955     Dell   Gaming    17.3  IPS Panel 4K Ultra HD 3840x2160
# 1197    Asus   Gaming    17.3      IPS Panel Full HD 1920x1080
#
# ...

# %%
df['Primary_Storage'].value_counts()
# Out:
# Primary_Storage
# 256GB SSD       420
# 1TB HDD         223
# 500GB HDD       132
# 512GB SSD       120
# 128GB SSD        96
# 256GB SSD        88
# 128GB SSD        80
# 32GB SSD         44
# 512GB SSD        20
# 64GB SSD         16
# 2TB HDD          16
# 1TB SSD          14
# 16GB SSD         10
# 1.0TB Hybrid      9
# 180GB SSD         5
# 1TB SSD           2
# 64GB SSD          1
# 1TB HDD           1
# 32GB HDD          1
# 128GB HDD         1
# 240GB SSD         1
# 8GB SSD           1
# 508GB Hybrid      1
# 1.0TB HDD         1
# Name: count, dtype: int64

# %%
df['Primary_Storage'].str.extract(r'(\d+\.\d+|\d+)')
# Out:
#         0
# 0     128
# 1     128
# 2     256
# 3     512
# 4     256
# ...   ...
# 1298  128
# 1299  512
# 1300   64
# 1301    1
# 1302  500
#
# [1303 rows x 1 columns]

# %%
import re
def tb2gb(text):
    if 'tb' in text.lower():
        # Extract the number (integer or float) from the text
        match = re.search(r'(\d+\.\d+|\d+)', text)
        if match:
            num = float(match.group())  # Convert the extracted number to float
            gb_value = num * 1024  # Convert TB to GB
            return gb_value
        else:
            return None
    else:
        return int(text.split('GB')[0])

# %%
df['Primary_Storage'] = df['Primary_Storage'].apply(tb2gb).astype(int)

# %%
df['Primary_Storage']
# Out:
# 0        128
# 1        128
# 2        256
# 3        512
# 4        256
#         ...
# 1298     128
# 1299     512
# 1300      64
# 1301    1024
# 1302     500
# Name: Primary_Storage, Length: 1303, dtype: int32

# %%
df['Secondary_Storage']
# Out:
# 0       0GB
# 1       0GB
# 2       0GB
# 3       0GB
# 4       0GB
#        ...
# 1298    0GB
# 1299    0GB
# 1300    0GB
# 1301    0GB
# 1302    0GB
# Name: Secondary_Storage, Length: 1303, dtype: object

# %%
df['Secondary_Storage'] = df['Secondary_Storage'].apply(tb2gb).astype(int)

# %%
df.drop(columns=['Primary_Storage1'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[422], line 1
# ----> 1 df.drop(columns=['Primary_Storage1'],inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df[df['Company']=='Apple']
# Out:
#      Company   TypeName  Inches                    ScreenResolution  \
# 0      Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1      Apple  Ultrabook    13.3                            1440x900
# 3      Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4      Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 6      Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 7      Apple  Ultrabook    13.3                            1440x900
# 12     Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 14     Apple  Ultrabook    12.0  IPS Panel Retina Display 2304x1440
# 15     Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 17     Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 26     Apple  Ultrabook    13.3                            1440x900
# 34     Apple  Ultrabook    13.3                            1440x900
# 45     Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# ...

# %%
def gpu_brand(text):
    if 'nvidia' in text.lower():
        return 'Nvidia'
    elif 'amd' in text.lower():
        return 'AMD'
    elif 'intel' in text.lower():
        return 'Intel'
    else:
        return 'Other'

# %%
df['GPU'] = df['Gpu'].apply(gpu_brand)

# %%
df['GPU'].value_counts()
# Out:
# GPU
# Intel     722
# Nvidia    400
# AMD       180
# Other       1
# Name: count, dtype: int64

# %%
df[df['GPU'] == 'Other']
# Out:
#       Company            TypeName  Inches                 ScreenResolution  \
# 1191  Samsung  2 in 1 Convertible    12.3  IPS Panel Touchscreen 2400x1600
#
#                                 Cpu  Ram              Memory  \
# 1191  Samsung Cortex A72&A53 2.0GHz  4GB  32GB Flash Storage
#
#                     Gpu      OpSys  Weight  ...  h_pixel v_pixel megapixel  \
# 1191  ARM Mali T860 MP4  Chrome OS  1.15kg  ...     2400    1600       3.8
#
#      CPU_Brand  RAM  Primary_Storage  Secondary_Storage Primary_type  \
# 1191     Other    4               32                  0          SSD
#
#       Secondary_type    GPU
# 1191             HDD  Other
#
# [1 rows x 24 columns]

# %%
df['CPU_Brand'].value_counts()
# Out:
# CPU_Brand
# Intel    1240
# AMD        62
# Other       1
# Name: count, dtype: int64

# %%
df['Weight'].value_counts()
# Out:
# Weight
# 2.2kg     121
# 2.1kg      58
# 2.4kg      44
# 2.3kg      41
# 2.5kg      38
#          ...
# 3.25kg      1
# 4.7kg       1
# 1.55kg      1
# 1.18kg      1
# 4.0kg       1
# Name: count, Length: 179, dtype: int64

# %%
df['WEIGHT'] = df['Weight'].apply(lambda x:x.split('kg')[0]).astype(float)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'Price', 'OS', 'Display_type',
#        'Screen_Resolution', 'h_pixel', 'v_pixel', 'megapixel', 'CPU_Brand',
#        'RAM', 'Primary_Storage', 'Secondary_Storage', 'Primary_type',
#        'Secondary_type', 'GPU', 'WEIGHT'],
#       dtype='object')

# %%
df_fin = df[['Company', 'TypeName', 'Inches','Price', 'OS', 'Display_type',
             'h_pixel', 'v_pixel', 'megapixel', 'CPU_Brand',
       'RAM', 'Primary_Storage', 'Secondary_Storage', 'Primary_type',
       'Secondary_type', 'GPU', 'WEIGHT']]

# %%
df_fin
# Out:
#      Company            TypeName  Inches        Price          OS  \
# 0      Apple           Ultrabook    13.3   71378.6832      Mac OS
# 1      Apple           Ultrabook    13.3   47895.5232      Mac OS
# 2         HP            Notebook    15.6   30636.0000    Other OS
# 3      Apple           Ultrabook    15.4  135195.3360      Mac OS
# 4      Apple           Ultrabook    13.3   96095.8080      Mac OS
# ...      ...                 ...     ...          ...         ...
# 1298  Lenovo  2 in 1 Convertible    14.0   33992.6400  Windows OS
# 1299  Lenovo  2 in 1 Convertible    13.3   79866.7200  Windows OS
# 1300  Lenovo            Notebook    14.0   12201.1200  Windows OS
# 1301      HP            Notebook    15.6   40705.9200  Windows OS
# 1302    Asus            Notebook    15.6   19660.3200  Windows OS
#
#      Display_type  h_pixel  v_pixel  megapixel CPU_Brand  RAM  \
# 0             IPS     2560     1600        4.1     Intel    8
# ...

# %%
df_fin.to_csv('preprocessed_data.csv',index=False)

# %%
catcols = [x for x in df_fin.columns if df_fin[x].dtype=='object']
catcols
# Out:
# ['Company',
#  'TypeName',
#  'OS',
#  'Display_type',
#  'CPU_Brand',
#  'Primary_type',
#  'Secondary_type',
#  'GPU']

# %%
num_features = len(catcols)
rows = np.ceil(np.sqrt(num_features)).astype(int)
cols = np.ceil(num_features / rows).astype(int)
print(rows,cols)
# Out:
# 3 3

# %%
fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 5 * rows))  # Dynamic figure size
axes = axes.flatten()

for i, feature in enumerate(catcols):
    sns.barplot(data=df_fin, y='Price', x=feature, ax=axes[i])
    axes[i].set_title(feature)
    axes[i].tick_params(axis='x', rotation=90)

# Turn off unused axes
for i in range(len(catcols), len(axes)):
    axes[i].axis('off') 
plt.tight_layout()
plt.show()

# %%
df_fin.isna().sum()
# Out:
# Company              0
# TypeName             0
# Inches               0
# Price                0
# OS                   0
# Display_type         0
# h_pixel              0
# v_pixel              0
# megapixel            0
# CPU_Brand            0
# RAM                  0
# Primary_Storage      0
# Secondary_Storage    0
# Primary_type         0
# Secondary_type       0
# GPU                  0
# WEIGHT               0
# dtype: int64

# %%
numcols = [x for x in df_fin.columns if df_fin[x].dtype!='object']
numcols
# Out:
# ['Inches',
#  'Price',
#  'h_pixel',
#  'v_pixel',
#  'megapixel',
#  'RAM',
#  'Primary_Storage',
#  'Secondary_Storage',
#  'WEIGHT']

# %%
num_features = len(numcols)
rows = np.ceil(np.sqrt(num_features)).astype(int)
cols = np.ceil(num_features / rows).astype(int)
print(rows,cols)
# Out:
# 3 3

# %%
fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 5 * rows))  # Dynamic figure size
axes = axes.flatten()

for i, feature in enumerate(numcols):
    sns.histplot(data=df_fin, x=feature, ax=axes[i])
    axes[i].set_title(feature)
    axes[i].tick_params(axis='x', rotation=90)

# Turn off unused axes
for i in range(len(numcols), len(axes)):
    axes[i].axis('off') 
plt.tight_layout()
plt.show()

# %% [markdown]
# # Log Values

# %%
fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 5 * rows))  # Dynamic figure size
axes = axes.flatten()

for i, feature in enumerate(numcols):
    sns.histplot(x=np.log(df_fin[feature]), ax=axes[i])
    axes[i].set_title(feature)
    axes[i].tick_params(axis='x', rotation=90)

# Turn off unused axes
for i in range(len(numcols), len(axes)):
    axes[i].axis('off') 
plt.tight_layout()
plt.show()
# Out:
# C:\Users\yashw\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 5 * rows))  # Dynamic figure size
axes = axes.flatten()

for i, feature in enumerate(numcols):
    sns.boxplot(x=df_fin[feature], ax=axes[i])
    axes[i].set_title(feature)
    axes[i].tick_params(axis='x', rotation=90)

# Turn off unused axes
for i in range(len(numcols), len(axes)):
    axes[i].axis('off') 
plt.tight_layout()
plt.show()

# %%
df_fin['Price'].quantile(q=[i / 100 for i in range(0, 101, 5)])
# Out:
# 0.00      9270.72000
# 0.05     16463.52000
# 0.10     20969.51616
# 0.15     24844.46400
# 0.20     28590.04800
# 0.25     31914.72000
# 0.30     35644.32000
# 0.35     39501.79200
# 0.40     43527.62880
# 0.45     47733.60528
# 0.50     52054.56000
# 0.55     56479.41072
# 0.60     60984.28800
# 0.65     64952.15616
# 0.70     71874.72000
# 0.75     79274.24640
# 0.80     87858.72000
# 0.85     97156.08000
# 0.90    108733.82400
# 0.95    130461.40800
# 1.00    324954.72000
# Name: Price, dtype: float64

# %%
upper_value = df_fin['Price'].quantile(0.95)
upper_value
# Out:
# 130461.40799999997

# %%
df1 = df_fin[df_fin['Price'] <= upper_value]

# %%
df1['WEIGHT'].quantile(q=[i / 100 for i in range(0, 101, 5)])
# Out:
# 0.00    0.690
# 0.05    1.178
# 0.10    1.260
# 0.15    1.344
# 0.20    1.412
# 0.25    1.500
# 0.30    1.630
# 0.35    1.800
# 0.40    1.894
# 0.45    1.960
# 0.50    2.040
# 0.55    2.100
# 0.60    2.180
# 0.65    2.200
# 0.70    2.200
# 0.75    2.300
# 0.80    2.400
# 0.85    2.500
# 0.90    2.650
# 0.95    2.900
# 1.00    4.600
# Name: WEIGHT, dtype: float64

# %%
lower_value = df1['WEIGHT'].quantile(0.05)
upper_value = df1['WEIGHT'].quantile(0.95)

# %%
df2 = df1[(df1['WEIGHT'] >= lower_value) &  (df1['WEIGHT'] <= upper_value)]

# %%
df2.shape
# Out:
# (1118, 17)

# %%
df1.shape
# Out:
# (1237, 17)

# %%
df2['log_price'] = np.log(df2['Price'])
df2
# Out:
# C:\Users\yashw\AppData\Local\Temp\ipykernel_33040\3683877971.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['log_price'] = np.log(df2['Price'])
#      Company            TypeName  Inches       Price          OS Display_type  \
# 0      Apple           Ultrabook    13.3  71378.6832      Mac OS          IPS
# 1      Apple           Ultrabook    13.3  47895.5232      Mac OS  Other Types
# 2         HP            Notebook    15.6  30636.0000    Other OS  Other Types
# 4      Apple           Ultrabook    13.3  96095.8080      Mac OS          IPS
# 5       Acer            Notebook    15.6  21312.0000  Windows OS  Other Types
# ...      ...                 ...     ...         ...         ...          ...
# ...

# %%
fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 5 * rows))  # Dynamic figure size
axes = axes.flatten()

for i, feature in enumerate(numcols):
    sns.boxplot(x=df2[feature], ax=axes[i])
    axes[i].set_title(feature)
    axes[i].tick_params(axis='x', rotation=90)

# Turn off unused axes
for i in range(len(numcols), len(axes)):
    axes[i].axis('off') 
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 5 * rows))  # Dynamic figure size
axes = axes.flatten()

for i, feature in enumerate(numcols):
    sns.scatterplot(x=feature,y='log_price',data=df2, ax=axes[i])
    axes[i].set_title(feature)

# Turn off unused axes
for i in range(len(numcols), len(axes)):
    axes[i].axis('off') 
plt.tight_layout()
plt.show()

# %%
def freq_encoding(col_list,df):
    new_df = pd.DataFrame()
    for col in col_list:
        freq_dict = df[col].value_counts().to_dict()
        new_df[col] = df[col].map(freq_dict)
    return new_df

# %%
df_enc = freq_encoding(catcols,df2)

# %%
df_enc
# Out:
#       Company  TypeName   OS  Display_type  CPU_Brand  Primary_type  \
# 0          12       150   12           271       1060           748
# 1          12       150   12           763       1060           748
# 2         247       704   87           763       1060           748
# 4          12       150   12           271       1060           748
# 5          92       704  958           763         58           370
# ...       ...       ...  ...           ...        ...           ...
# 1298      260       104  958           271       1060           748
# 1299      260       104  958           271       1060           748
# 1300      260       704  958           763       1060           748
# 1301      247       704  958           763       1060           370
# 1302      120       704  958           763       1060           370
#
#       Secondary_type  GPU
# 0               1116  646
# 1               1116  646
# 2               1116  646
# 4               1116  646
# ...

# %%
df_enc['log_price'] = df2['log_price']
df_enc
# Out:
#       Company  TypeName   OS  Display_type  CPU_Brand  Primary_type  \
# 0          12       150   12           271       1060           748
# 1          12       150   12           763       1060           748
# 2         247       704   87           763       1060           748
# 4          12       150   12           271       1060           748
# 5          92       704  958           763         58           370
# ...       ...       ...  ...           ...        ...           ...
# 1298      260       104  958           271       1060           748
# 1299      260       104  958           271       1060           748
# 1300      260       704  958           763       1060           748
# 1301      247       704  958           763       1060           370
# 1302      120       704  958           763       1060           370
#
#       Secondary_type  GPU  log_price
# 0               1116  646  11.175755
# 1               1116  646  10.776777
# ...

# %%
df_enc.corr()['log_price']
# Out:
# Company           0.043405
# TypeName         -0.531336
# OS                0.299856
# Display_type     -0.329544
# CPU_Brand         0.252880
# Primary_type      0.460877
# Secondary_type   -0.040241
# GPU              -0.072322
# log_price         1.000000
# Name: log_price, dtype: float64

# %%
numcols = ['Inches',
 'megapixel',
 'RAM',
 'Primary_Storage',
 'Secondary_Storage']

# %%
df_enc['Weight'] = df2['WEIGHT']

# %%
df_comb = pd.concat([df_enc,df2[numcols]],axis=1)
df_comb.shape
# Out:
# (1118, 15)

# %%
df_comb
# Out:
#       Company  TypeName   OS  Display_type  CPU_Brand  Primary_type  \
# 0          12       150   12           271       1060           748
# 1          12       150   12           763       1060           748
# 2         247       704   87           763       1060           748
# 4          12       150   12           271       1060           748
# 5          92       704  958           763         58           370
# ...       ...       ...  ...           ...        ...           ...
# 1298      260       104  958           271       1060           748
# 1299      260       104  958           271       1060           748
# 1300      260       704  958           763       1060           748
# 1301      247       704  958           763       1060           370
# 1302      120       704  958           763       1060           370
#
#       Secondary_type  GPU  log_price  Weight  Inches  megapixel  RAM  \
# 0               1116  646  11.175755    1.37    13.3        4.1    8
# ...

# %%
df_comb.corr()['log_price']
# Out:
# Company              0.043405
# TypeName            -0.531336
# OS                   0.299856
# Display_type        -0.329544
# CPU_Brand            0.252880
# Primary_type         0.460877
# Secondary_type      -0.040241
# GPU                 -0.072322
# log_price            1.000000
# Weight              -0.110673
# Inches              -0.116484
# megapixel            0.474634
# RAM                  0.669831
# Primary_Storage     -0.210102
# Secondary_Storage    0.263030
# Name: log_price, dtype: float64

# %% [markdown]
# # tried scaling with min max scaler, but it was reducing the correlation with the log price feature, hence removed the scaling from the process

# %%
df_comb.to_csv('data_encoded.csv',index=False)

# %%
import json

def save_dict_to_json(dictionary, file_name):
    """
    Save a dictionary to a JSON file.

    Parameters:
    dictionary (dict): The dictionary to save.
    file_name (str): The name of the JSON file.
    """
    try:
        with open(file_name, 'w') as json_file:
            json.dump(dictionary, json_file, indent=4)  # Format the JSON file for readability
        print(f"Dictionary successfully saved to {file_name}!")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
# storing dictionary for the cateogrical features

def freq_encoding(col_list,df):
    new_df = pd.DataFrame()
    for col in col_list:
        freq_dict = df[col].value_counts().to_dict()
        save_dict_to_json(freq_dict,f'{col}.json')
        new_df[col] = df[col].map(freq_dict)
    return new_df

# %%
new1 = freq_encoding(catcols,df2)
# Out:
# Dictionary successfully saved to Company.json!
# Dictionary successfully saved to TypeName.json!
# Dictionary successfully saved to OS.json!
# Dictionary successfully saved to Display_type.json!
# Dictionary successfully saved to CPU_Brand.json!
# Dictionary successfully saved to Primary_type.json!
# Dictionary successfully saved to Secondary_type.json!
# Dictionary successfully saved to GPU.json!
